# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.ticker import StrMethodFormatter

# %%
import numpy as np

# %%
# !pip3 install pyreadstat

# %% [markdown]
# # READ SAV FILES

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section b.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanB.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhB.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabB.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkB.csv')
# data = province.get_group('AJK')
# data.to_csv('/content/drive/My Drive/csv files/2006-07/ajkB.csv')
# data = province.get_group('FATA')
# data.to_csv('/content/drive/My Drive/csv files/2006-07/fataB.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section c.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanC.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhC.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabC.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkC.csv')
# data = province.get_group('AJK')
# data.to_csv('/content/drive/My Drive/csv files/2006-07/ajkC.csv')
# data = province.get_group('FATA')
# data.to_csv('/content/drive/My Drive/csv files/2006-07/fataC.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section d.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanD.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhD.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabD.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkD.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section e.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanE.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhE.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabE.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkE.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section f1.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanF1.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhF1.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabF1.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkF1.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section f2.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanF2.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhF2.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabF2.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkF2.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section G.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanG.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhG.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabG.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkG.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section h.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanH.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhH.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabH.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkH.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section i.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2006-07/balochistanI.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2006-07/sindhI.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2006-07/punjabI.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2006-07/kpkI.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/sec b.sav')
province = df.groupby('province')
data = province.get_group(4)
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanB.csv')
data = province.get_group(2)
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhB.csv')
data = province.get_group(1)
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabB.csv')
data = province.get_group(3)
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkB.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/sec c.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanC.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhC.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabC.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkC.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/sec d.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanD.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhD.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabD.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkD.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/section e.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanE.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhE.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabE.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkE.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/section_f1.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanF1.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhF1.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabF1.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkF1.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/section_f2.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanF2.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhF2.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabF2.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkF2.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/section_g.sav')
province = df.groupby('PROVINCE')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanG.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhG.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabG.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkG.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/section_h.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanH.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhH.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabH.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkH.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/section_i.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanI.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhI.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabI.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkI.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2008-09 Microdata/section_j.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2008-09/balochistanJ.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2008-09/sindhJ.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2008-09/punjabJ.csv')
data = province.get_group('NWFP')
data.to_csv('/content/drive/My Drive/csv files/2008-09/kpkJ.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec B_dist.sav')

# %%
df.to_csv('/content/drive/My Drive/csv files/kpk.csv')

# %%
province = df.groupby('province')

# %%
data = province.get_group('Khyber Pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/kpk.csv')

# %% [markdown]
# #ASNA

# %%
#Asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/section_D.sav')

# %%
df

# %%
#Asna
province = df.groupby('PROVINCE')

# %%
#Asna
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/balochistanD.csv')

# %%
#Asna
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/sindhD.csv')

# %%
#Asna
data = province.get_group('Khyberpakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/kpkD.csv')

# %%
#Asna
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/punjabD.csv')

# %%
#Asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/Sec F1_dis.sav')

# %%
#Asna
df

# %%
#Asna
province = df.groupby('province')

# %%
#Asna
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/balochistanF1.csv')

# %%
#Asna
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/punjabF1.csv')

# %%
#Asna
data = province.get_group('Khyber pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/kpkF1.csv')

# %%
#Asna
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/sindhF1.csv')

# %%
#Asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/Sec G_dis.sav')

# %%
#Asna
df

# %%
#Asna
province = df.groupby('province')

# %%
#Asna
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/punjabG.csv')

# %%
#Asna
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/sindhG.csv')

# %%
#Asna
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/balochistanG.csv')

# %%
#Asna
data = province.get_group('Khyber pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/kpkG.csv')

# %%
#Asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/section_h.sav')

# %%
#Asna
df

# %%
#Asna
province = df.groupby('province')

# %%
#Asna
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/punjabH.csv')

# %%
#Asna
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/sindhH.csv')

# %%
#Asna
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/balochistanH.csv')

# %%
#Asna
data = province.get_group('Khyberpakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/kpkH.csv')

# %%
#Asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/section_I.sav')

# %%
#Asna
df

# %%
#Asna
province = df.groupby('province')

# %%
#Asna
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/punjabI.csv')

# %%
#Asna
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/sindhI.csv')

# %%
#Asna
data = province.get_group('Khyberpakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/kpkI.csv')

# %%
#Asna
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/balochistanJ.csv')

# %%
#Asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/Sec J_Dis.sav')

# %%
#Asna
df

# %%
#Asna
province = df.groupby('province')

# %%
#Asna
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/sindhJ.csv')

# %%
#Asna
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/balochistanJ.csv')

# %%
#Asna
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/punjabJ.csv')

# %%
#Asna
data = province.get_group('Khyber pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/kpkJ.csv')

# %% [markdown]
# #ZU

# %%
#zu
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/Sec F1_dis.sav')

# %%
#zu 
df

# %%
#zu
district = df.groupby('district')

# %%
#zu
data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/IslamabadF1.csv')

# %%
#zu
data = district.get_group('Bolan/Kacchi')
data.to_csv('/content/drive/My Drive/csv files/BolanKacchiF1.csv')

# %%
#zu
data = district.get_group('Attock')
data.to_csv('/content/drive/My Drive/csv files/AttockF1.csv')

# %%
#zu
data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/RawalpindiF1.csv')

# %%
#zu
data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/JehlumF1.csv')

# %%
#zu
data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/ChakwalF1.csv')

# %%
#zu
data = district.get_group('Sargodha')
data.to_csv('/content/drive/My Drive/csv files/SargodhaF1.csv')

# %%
#zu
data = district.get_group('Bhakhar')
data.to_csv('/content/drive/My Drive/csv files/BhakharF1.csv')

# %%
#zu
data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/KhushabF1.csv')

# %%
#zu
data = district.get_group('Mianwali')
data.to_csv('/content/drive/My Drive/csv files/MianwaliF1.csv')

# %%
#zu
data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/FaisalabadF1.csv')

# %%
#zu
data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/JhangF1.csv')

# %%
#zu
data = district.get_group('T.T.Singh')
data.to_csv('/content/drive/My Drive/csv files/T.T.SinghF1.csv')

# %%
#zu
data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/ChiniotF1.csv')

# %%
#zu
data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/GujranwalaF1.csv')

# %%
#zu
data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/GujratF1.csv')

# %%
#zu
data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/SialkotF1.csv')

# %%
#zu
data = district.get_group('Hafizabad')
data.to_csv('/content/drive/My Drive/csv files/HafizabadF1.csv')

# %%
#zu
data = district.get_group('Mandi Bahuddin')
data.to_csv('/content/drive/My Drive/csv files/district/MandiBahuddinF1.csv')

# %%
#zu
data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/district/NarowalF1.csv')

# %%
#zu
data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/district/LahoreF1.csv')

# %%
#zu
data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/district/KasurF1.csv')

# %%
#zu
data = district.get_group('Sheikupura')
data.to_csv('/content/drive/My Drive/csv files/district/SheikupuraF1.csv')

# %%
#zu
data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/district/NankanaSahibF1.csv')

# %%
#zu
data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/district/VehariF1.csv')

# %%
#zu
data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/district/MultanF1.csv')

# %%
#zu
data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/district/KhanewalF1.csv')

# %%
#zu
data = district.get_group('Lodhran')
data.to_csv('/content/drive/My Drive/csv files/district/LodhranF1.csv')

# %%
#zu
data = district.get_group('D.G.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/DGKhanF1.csv')

# %%
#zu
data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/district/RajanpurF1.csv')

# %%
#zu
data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/district/LayyahF1.csv')

# %%
#zu
data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/district/MuzzaffargarhF1.csv')

# %%
#zu
data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalpurF1.csv')

# %%
#zu
data = district.get_group('Bahawalnagar')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalnagarF1.csv')

# %%
#zu
data = district.get_group("RahimYar Khan'")
data.to_csv('/content/drive/My Drive/csv files/district/RahimYar KhanF1.csv')

# %%
#zu
data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/district/SahiwalF1.csv')

# %%
#zu
data = district.get_group('Pakputten')
data.to_csv('/content/drive/My Drive/csv files/district/PakputtenF1.csv')

# %%
#zu
data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/district/OkaraF1.csv')

# %%
#zu
data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/district/KhairpurF1.csv')

# %%
#zu
data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/district/SukkurF1.csv')

# %%
#zu
data = district.get_group('Nawabshah')
data.to_csv('/content/drive/My Drive/csv files/district/NawabshahF1.csv')

# %%
#zu
data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/district/NowsheroferozeF1.csv')

# %%
#zu
data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/district/GhotkiF1.csv')

# %%
#zu
data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/district/JaccobabadF1.csv')

# %%
#zu
data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/district/KashmoreF1.csv')

# %%
#zu
data = district.get_group('Shikarpur')
data.to_csv('/content/drive/My Drive/csv files/district/ShikarpurF1.csv')

# %%
#zu
data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/district/LarkanaF1.csv')

# %%
#zu
data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/district/ShahdadkotF1.csv')

# %%
#zu
data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/district/DaduF1.csv')

# %%
#zu
data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/district/JamshoroF1.csv')

# %%
#zu
data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/district/HyderabadF1.csv')

# %%
#zu
data = district.get_group('Maitari')
data.to_csv('/content/drive/My Drive/csv files/district/MaitariF1.csv')

# %%
#zu
data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/district/TandoallahyarF1.csv')

# %%
#zu
data = district.get_group('Tando Muda khan')
data.to_csv('/content/drive/My Drive/csv files/district/TandomudakhanF1.csv')

# %%
#zu
data = district.get_group('Badin')
data.to_csv('/content/drive/My Drive/csv files/district/BadinF1.csv')

# %%
#zu
data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/district/ThattaF1.csv')


data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/district/SangharF1.csv')

# %%
#zu
data = district.get_group('Mir Pur Khas')
data.to_csv('/content/drive/My Drive/csv files/district/MirpurkhasF1.csv')

data = district.get_group('Umer Kot')
data.to_csv('/content/drive/My Drive/csv files/district/UmerkotF1.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/district/TharparkarF1.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/district/KarachiF1.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/district/SwatF1.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/district/UpperdirF1.csv')

# %%
#zu
data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/district/LowerdirF1.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/district/ChitralF1.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/district/ShanglaF1.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/district/MalakandF1.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/district/BonairF1.csv')

data = district.get_group('Peshawar')
data.to_csv('/content/drive/My Drive/csv files/district/PeshawarF1.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/district/CharsadaF1.csv')

data = district.get_group('Nowshera')
data.to_csv('/content/drive/My Drive/csv files/district/NaowsheraF1.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/district/KohatF1.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/district/KarakF1.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/district/HanguF1.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/DikhanF1.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/district/TankF1.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/district/MansheraF1.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/district/AbbottabadF1.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/district/BatagramF1.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/district/KohistanF1.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/district/HaripurF1.csv')

data = district.get_group('Bannu')
data.to_csv('/content/drive/My Drive/csv files/district/BannuF1.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/district/LakkimarwatF1.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/district/MardanF1.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/district/SwabiF1.csv')

# %% [markdown]
# # ASNA

# %%
#asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec B_dist.sav')
district = df.groupby('dist')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/district/IslamabadB.csv')

# data = district.get_group('Attock')
# data.to_csv('/content/drive/My Drive/csv files/district/AttockB.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/district/RawalpindiB.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/district/JehlumB.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/district/ChakwalB.csv')

data = district.get_group('Sargodha')
data.to_csv('/content/drive/My Drive/csv files/district/SargodhaB.csv')

data = district.get_group('Bhakhar')
data.to_csv('/content/drive/My Drive/csv files/district/BhakharB.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/district/KhushabB.csv')

data = district.get_group('Mianwali')
data.to_csv('/content/drive/My Drive/csv files/district/MianwaliB.csv')

data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/district/FaisalabadB.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/district/JhangB.csv')

data = district.get_group('T.T.Singh')
data.to_csv('/content/drive/My Drive/csv files/district/T.T.SinghB.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/district/ChiniotB.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/district/GujranwalaB.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/district/GujratB.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/district/SialkotB.csv')

data = district.get_group('Hafizabad')
data.to_csv('/content/drive/My Drive/csv files/district/HafizabadB.csv')

data = district.get_group('Mandi Bahuddin')
data.to_csv('/content/drive/My Drive/csv files/district/Mandi BahuddinB.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/district/NarowalB.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/district/LahoreB.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/district/KasurB.csv')

data = district.get_group('Sheikupura')
data.to_csv('/content/drive/My Drive/csv files/district/SheikupuraB.csv')

# %%
data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/district/Nankana SahibB.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/district/VehariB.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/district/MultanB.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/district/KhanewalB.csv')

data = district.get_group('Lodhran')
data.to_csv('/content/drive/My Drive/csv files/district/LodhranB.csv')

data = district.get_group('D.G.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/D.G.KhanB.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/district/RajanpurB.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/district/LayyahB.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/district/Muzaffar GarhB.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalpurB.csv')

data = district.get_group('Bahawalnagar')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalnagarB.csv')

data = district.get_group('RahimYar Khan')
data.to_csv('/content/drive/My Drive/csv files/district/RahimYar KhanB.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/district/SahiwalB.csv')

data = district.get_group('Pakpattan')
data.to_csv('/content/drive/My Drive/csv files/district/PakpattanB.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/district/OkaraB.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/district/KhairpurB.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/district/SukkurB.csv')

data = district.get_group('Nawabshah')
data.to_csv('/content/drive/My Drive/csv files/district/NawabshahB.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/district/Nowshero FerozeB.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/district/ghotkiB.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/district/JaccobabadB.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/district/KashmoreB.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec B_dist.sav')
district = df.groupby('dist')

data = district.get_group('Shikarpur')
data.to_csv('/content/drive/My Drive/csv files/district/ShikarpurB.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/district/LarkanaB.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/district/ShahdadkotB.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/district/KhanewalB.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/district/DaduB.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/district/JamshoroB.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/district/HyderabadB.csv')

data = district.get_group('Maitari')
data.to_csv('/content/drive/My Drive/csv files/district/MaitariB.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/district/Tando Allah YarB.csv')

data = district.get_group('Tando Muda khan')
data.to_csv('/content/drive/My Drive/csv files/district/Tando Muda khanB.csv')

data = district.get_group('Badin')
data.to_csv('/content/drive/My Drive/csv files/district/BadinB.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/district/ThattaB.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/district/SangharB.csv')

data = district.get_group('Mir Pur Khas')
data.to_csv('/content/drive/My Drive/csv files/district/Mir Pur KhasB.csv')

data = district.get_group('Umer kot')
data.to_csv('/content/drive/My Drive/csv files/district/Umer kotB.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/district/TharparkarB.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/district/KarachiB.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/district/SwatB.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/district/Upper DirB.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/district/Lower DirB.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/district/ChitralB.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/district/ShanglaB.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec B_dist.sav')
district = df.groupby('dist')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/district/MalakandB.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/district/BonairB.csv')

data = district.get_group('Peshawar')
data.to_csv('/content/drive/My Drive/csv files/district/PeshawarB.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/district/CharsadaB.csv')

data = district.get_group('Nowshera')
data.to_csv('/content/drive/My Drive/csv files/district/NowsheraB.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/district/KohatB.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/district/KarakB.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/district/HanguB.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/D.I.KhanB.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/district/TankB.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/district/MansheraB.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/district/AbbottabadB.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/district/BatagramB.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/district/KohistanB.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/district/HaripurB.csv')

data = district.get_group('Bannu')
data.to_csv('/content/drive/My Drive/csv files/district/BannuB.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/district/Lakki MarwatB.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/district/MardanB.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/district/SwabiB.csv')

data = district.get_group('Quetta')
data.to_csv('/content/drive/My Drive/csv files/district/QuettaB.csv')

data = district.get_group('Pashin')
data.to_csv('/content/drive/My Drive/csv files/district/PashinB.csv')

data = district.get_group('Qillah abdullah')
data.to_csv('/content/drive/My Drive/csv files/district/Qillah abdullahB.csv')

data = district.get_group('Chagi')
data.to_csv('/content/drive/My Drive/csv files/district/ChagiB.csv')

data = district.get_group('Nushki')
data.to_csv('/content/drive/My Drive/csv files/district/NushkiB.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/district/SibbiB.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/district/ZiaratB.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/district/KohluB.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/district/Dera BugtiB.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/district/HarnaiB.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/district/KalatB.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/district/MastungB.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/district/KhuzdarB.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/district/AwaranB.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/district/KharanB.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/district/WashukB.csv')

data = district.get_group('Lasbilla')
data.to_csv('/content/drive/My Drive/csv files/district/LasbillanB.csv')

data = district.get_group('Ketch/Turbat')
data.to_csv('/content/drive/My Drive/csv files/district/KetchTurbatB.csv')

data = district.get_group('Gwadar')
data.to_csv('/content/drive/My Drive/csv files/district/GwadarB.csv')

data = district.get_group('Panjgur')
data.to_csv('/content/drive/My Drive/csv files/district/PanjgurB.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/district/ZhobB.csv')

data = district.get_group('Lorali')
data.to_csv('/content/drive/My Drive/csv files/district/LoraliB.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/district/BarkhanB.csv')

data = district.get_group('Musakhel')
data.to_csv('/content/drive/My Drive/csv files/district/MusakhelB.csv')

data = district.get_group('Qillah Saifuallh')
data.to_csv('/content/drive/My Drive/csv files/district/Qillah SaifuallhB.csv')

data = district.get_group('Sherani')
data.to_csv('/content/drive/My Drive/csv files/district/SheraniB.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/district/NasirabadB.csv')

data = district.get_group('Jafarabad')
data.to_csv('/content/drive/My Drive/csv files/district/JafarabadB.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/district/Jhal MagsiB.csv')

data = district.get_group('Bolan/Kacchi')
data.to_csv('/content/drive/My Drive/csv files/district/BolanKacchiB.csv')

# %%
#asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec C_dist.sav')
district = df.groupby('District')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/district/IslamabadC.csv')

# data = district.get_group('Attock')
# data.to_csv('/content/drive/My Drive/csv files/district/AttockC.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/district/RawalpindiC.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/district/JehlumC.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/district/ChakwalC.csv')

data = district.get_group('Sargodha')
data.to_csv('/content/drive/My Drive/csv files/district/SargodhaC.csv')

data = district.get_group('Bhakhar')
data.to_csv('/content/drive/My Drive/csv files/district/BhakharC.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/district/KhushabC.csv')

data = district.get_group('Mianwali')
data.to_csv('/content/drive/My Drive/csv files/district/MianwaliC.csv')

data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/district/FaisalabadC.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/district/JhangC.csv')

data = district.get_group('T.T.Singh')
data.to_csv('/content/drive/My Drive/csv files/district/T.T.SinghC.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/district/ChiniotC.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/district/GujranwalaC.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/district/GujratC.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/district/SialkotC.csv')

data = district.get_group('Hafizabad')
data.to_csv('/content/drive/My Drive/csv files/district/HafizabadC.csv')

data = district.get_group('Mandi Bahuddin')
data.to_csv('/content/drive/My Drive/csv files/district/Mandi BahuddinC.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/district/NarowalC.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/district/LahoreC.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/district/KasurC.csv')

data = district.get_group('Sheikupura')
data.to_csv('/content/drive/My Drive/csv files/district/SheikupuraC.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/district/Nankana SahibC.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/district/VehariC.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/district/MultanC.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/district/KhanewalC.csv')

data = district.get_group('Lodhran')
data.to_csv('/content/drive/My Drive/csv files/district/LodhranC.csv')

data = district.get_group('D.G.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/D.G.KhanC.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/district/RajanpurC.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/district/LayyahC.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/district/Muzaffar GarhC.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalpurC.csv')

data = district.get_group('Bahawalnagar')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalnagarC.csv')

data = district.get_group('RahimYar Khan')
data.to_csv('/content/drive/My Drive/csv files/district/RahimYar KhanC.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/district/SahiwalC.csv')

data = district.get_group('Pakpattan')
data.to_csv('/content/drive/My Drive/csv files/district/PakpattanC.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/district/OkaraC.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/district/KhairpurC.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/district/SukkurC.csv')

data = district.get_group('Nawabshah')
data.to_csv('/content/drive/My Drive/csv files/district/NawabshahC.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/district/Nowshero FerozeC.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/district/GhotkiC.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/district/JaccobabadC.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/district/KashmoreC.csv')

data = district.get_group('Shikarpur')
data.to_csv('/content/drive/My Drive/csv files/district/ShikarpurC.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/district/LarkanaC.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/district/ShahdadkotC.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/district/KhanewalC.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/district/DaduC.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/district/JamshoroC.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/district/HyderabadC.csv')

data = district.get_group('Maitari')
data.to_csv('/content/drive/My Drive/csv files/district/MaitariC.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/district/Tando Allah YarC.csv')

data = district.get_group('Tando Muda khan')
data.to_csv('/content/drive/My Drive/csv files/district/Tando Muda khanC.csv')

data = district.get_group('Badin')
data.to_csv('/content/drive/My Drive/csv files/district/BadinC.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/district/ThattaC.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/district/SangharC.csv')

data = district.get_group('Mir Pur Khas')
data.to_csv('/content/drive/My Drive/csv files/district/Mir Pur KhasC.csv')

data = district.get_group('Umer kot')
data.to_csv('/content/drive/My Drive/csv files/district/Umer kotC.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/district/TharparkarC.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/district/KarachiC.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/district/SwatC.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/district/Upper DirC.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/district/Lower DirC.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/district/ChitralC.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/district/ShanglaC.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/district/MalakandC.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/district/BonairC.csv')

data = district.get_group('Peshawar')
data.to_csv('/content/drive/My Drive/csv files/district/PeshawarC.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/district/CharsadaC.csv')

data = district.get_group('Nowshera')
data.to_csv('/content/drive/My Drive/csv files/district/NowsheraC.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/district/KohatC.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/district/KarakC.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/district/HanguC.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/D.I.KhanC.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/district/TankC.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/district/MansheraC.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/district/AbbottabadC.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/district/BatagramC.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/district/KohistanC.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/district/HaripurC.csv')

data = district.get_group('Bannu')
data.to_csv('/content/drive/My Drive/csv files/district/BannuC.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/district/Lakki MarwatC.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/district/MardanC.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/district/SwabiC.csv')

data = district.get_group('Quetta')
data.to_csv('/content/drive/My Drive/csv files/district/QuettaC.csv')

data = district.get_group('Pashin')
data.to_csv('/content/drive/My Drive/csv files/district/PashinC.csv')

data = district.get_group('Qillah abdullah')
data.to_csv('/content/drive/My Drive/csv files/district/Qillah abdullahC.csv')

data = district.get_group('Chagi')
data.to_csv('/content/drive/My Drive/csv files/district/ChagiC.csv')

data = district.get_group('Nushki')
data.to_csv('/content/drive/My Drive/csv files/district/NushkiC.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/district/SibbiC.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/district/ZiaratC.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/district/KohluC.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/district/Dera BugtiC.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/district/HarnaiC.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/district/KalatC.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/district/MastungC.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/district/KhuzdarC.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/district/AwaranC.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/district/KharanC.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/district/WashukC.csv')

data = district.get_group('Lasbilla')
data.to_csv('/content/drive/My Drive/csv files/district/LasbillanC.csv')

data = district.get_group('Ketch/Turbat')
data.to_csv('/content/drive/My Drive/csv files/district/KetchTurbatC.csv')

data = district.get_group('Gwadar')
data.to_csv('/content/drive/My Drive/csv files/district/GwadarC.csv')

data = district.get_group('Panjgur')
data.to_csv('/content/drive/My Drive/csv files/district/PanjgurC.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/district/ZhobC.csv')

data = district.get_group('Lorali')
data.to_csv('/content/drive/My Drive/csv files/district/LoraliC.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/district/BarkhanC.csv')

data = district.get_group('Musakhel')
data.to_csv('/content/drive/My Drive/csv files/district/MusakhelC.csv')

data = district.get_group('Qillah Saifuallh')
data.to_csv('/content/drive/My Drive/csv files/district/Qillah SaifuallhC.csv')

data = district.get_group('Sherani')
data.to_csv('/content/drive/My Drive/csv files/district/SheraniC.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/district/NasirabadC.csv')

data = district.get_group('Jafarabad')
data.to_csv('/content/drive/My Drive/csv files/district/JafarabadC.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/district/Jhal MagsiC.csv')

data = district.get_group('Bolan/Kacchi')
data.to_csv('/content/drive/My Drive/csv files/district/BolanKacchiC.csv')

# %%
#asna
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec E_dist.sav')
district = df.groupby('District')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/district/IslamabadE.csv')

# data = district.get_group('Attock')
# data.to_csv('/content/drive/My Drive/csv files/district/AttockE.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/district/RawalpindiE.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/district/JehlumE.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/district/ChakwalE.csv')

data = district.get_group('Sargodha')
data.to_csv('/content/drive/My Drive/csv files/district/SargodhaE.csv')

data = district.get_group('Bhakhar')
data.to_csv('/content/drive/My Drive/csv files/district/BhakharE.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/district/KhushabE.csv')

data = district.get_group('Mianwali')
data.to_csv('/content/drive/My Drive/csv files/district/MianwaliE.csv')

data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/district/FaisalabadE.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/district/JhangE.csv')

data = district.get_group('T.T.Singh')
data.to_csv('/content/drive/My Drive/csv files/district/T.T.SinghE.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/district/ChiniotE.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/district/GujranwalaE.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/district/GujratE.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/district/SialkotE.csv')

data = district.get_group('Hafizabad')
data.to_csv('/content/drive/My Drive/csv files/district/HafizabadE.csv')

data = district.get_group('Mandi Bahuddin')
data.to_csv('/content/drive/My Drive/csv files/district/Mandi BahuddinE.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/district/NarowalE.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/district/LahoreE.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/district/KasurE.csv')

data = district.get_group('Sheikupura')
data.to_csv('/content/drive/My Drive/csv files/district/SheikupuraE.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/district/Nankana SahibE.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/district/VehariE.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/district/MultanE.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/district/KhanewalE.csv')

data = district.get_group('Lodhran')
data.to_csv('/content/drive/My Drive/csv files/district/LodhranE.csv')

data = district.get_group('D.G.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/D.G.KhanE.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/district/RajanpurE.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/district/LayyahE.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/district/Muzaffar GarhE.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalpurE.csv')

data = district.get_group('Bahawalnagar')
data.to_csv('/content/drive/My Drive/csv files/district/BahawalnagarE.csv')

data = district.get_group('RahimYar Khan')
data.to_csv('/content/drive/My Drive/csv files/district/RahimYar KhanE.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/district/SahiwalE.csv')

data = district.get_group('Pakpattan')
data.to_csv('/content/drive/My Drive/csv files/district/PakpattanE.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/district/OkaraE.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/district/KhairpurE.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/district/SukkurE.csv')

data = district.get_group('Nawabshah')
data.to_csv('/content/drive/My Drive/csv files/district/NawabshahE.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/district/Nowshero FerozeE.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/district/GhotkiE.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/district/JaccobabadE.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/district/KashmoreE.csv')

data = district.get_group('Shikarpur')
data.to_csv('/content/drive/My Drive/csv files/district/ShikarpurE.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/district/LarkanaE.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/district/ShahdadkotE.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/district/KhanewalE.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/district/DaduE.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/district/JamshoroE.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/district/HyderabadE.csv')

data = district.get_group('Maitari')
data.to_csv('/content/drive/My Drive/csv files/district/MaitariE.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/district/Tando Allah YarE.csv')

data = district.get_group('Tando Muda khan')
data.to_csv('/content/drive/My Drive/csv files/district/Tando Muda khanE.csv')

data = district.get_group('Badin')
data.to_csv('/content/drive/My Drive/csv files/district/BadinE.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/district/ThattaE.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/district/SangharE.csv')

data = district.get_group('Mir Pur Khas')
data.to_csv('/content/drive/My Drive/csv files/district/Mir Pur KhasE.csv')

data = district.get_group('Umer kot')
data.to_csv('/content/drive/My Drive/csv files/district/Umer kotE.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/district/TharparkarE.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/district/KarachiE.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/district/SwatE.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/district/Upper DirE.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/district/Lower DirE.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/district/ChitralE.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/district/ShanglaE.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/district/MalakandE.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/district/BonairE.csv')

data = district.get_group('Peshawar')
data.to_csv('/content/drive/My Drive/csv files/district/PeshawarE.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/district/CharsadaE.csv')

data = district.get_group('Nowshera')
data.to_csv('/content/drive/My Drive/csv files/district/NowsheraE.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/district/KohatE.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/district/KarakE.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/district/HanguE.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/district/D.I.KhanE.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/district/TankE.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/district/MansheraE.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/district/AbbottabadE.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/district/Batag
= province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec G/kpkG.csv')

# %%
#zu
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec H.sav')

df

# %%
#zu
province = df.groupby('province')

# %%
#zu
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec H/punjabH.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec H/sindhH.csv')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec H/balochistanH.csv')

data = province.get_group('Ïslamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec H/IslamabadH.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec H/kpkH.csv')

# %%
#zu
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec I.sav')

df

# %%
#zu
province = df.groupby('province')

# %%
#zu
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec I/punjabI.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec I/sindhI.csv')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec I/balochistanI.csv')

data = province.get_group('Ïslamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec I/IslamabadI.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec I/kpkI.csv')

# %%
#zu
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec J.sav')

df

# %%
#zu
province = df.groupby('province')

# %%
#zu
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec J/punjabJ.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec J/sindhJ.csv')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec J/balochistanJ.csv')

data = province.get_group('islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec J/IslamabadJ.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/province/Sec J/kpkJ.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/sec B.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanB.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhB.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabB.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkB.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec C.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanC.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhC.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabC.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkC.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec D.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanD.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhD.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabD.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkD.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec E.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanE.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhE.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabE.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkE.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec F1.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistaF1.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhF1.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabF1.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkF1.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec F2.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanF2.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhF2.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabF2.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkF2.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec G.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanG.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhG.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabG.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkG.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/sec H.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanH.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhH.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabH.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkH.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec  I.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanI.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhI.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabI.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkI.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2014-15 Microdata/Sec  J.sav')
province = df.groupby('province')
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2014-15/balochistanJ.csv')
data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2014-15/sindhJ.csv')
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2014-15/punjabJ.csv')
data = province.get_group('KP')
data.to_csv('/content/drive/My Drive/csv files/2014-15/kpkJ.csv')

# %% [markdown]
# # Remove white spaces
# 1) To remove white space at the beginning of string:
#
# df.columns = df.columns.str.lstrip()
#
# 2) To remove white space at the end of string:
#
# df.columns = df.columns.str.rstrip()

# %%
df = pd.read_spss('/content/drive/My Drive/new data/2006-07 Microdata/section b.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec B.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section c.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec C.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section d.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec D.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section e.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec E.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section f1.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec F1.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section f2.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec F2.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section G.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec G.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section h.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec H.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section i.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec I.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section j.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec J.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/sec b.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec B.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/sec c.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec C.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/sec d.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec D.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/section e.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec E.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/section_f1.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec F1.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/section_f2.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec F2.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/section_g.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec G.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/section_h.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec H.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/section_i.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec I.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2008-09 Microdata/section_j.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2008-2009/sec J.csv')

# %% [markdown]
# **2014-2015 Microdata**

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec  I.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec I.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec  J.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec J.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec A.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec A.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec C.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec C.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec D.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec D.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec E.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec E.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec F1.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec F1.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec F2.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec F2.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/Sec G.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec G.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/sec B.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec B.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2014-15 Microdata/sec H.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2014-2015/sec H.csv')

# %% [markdown]
# **2018-2019 MicroData**

# %% [markdown]
# **NEW SECTION**

# %%
df = pd.read_spss('/content/drive/My Drive/files with white spaces remove/new data/2006-07 Microdata/section e.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2006-2007/sec E.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec B_dist.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/sec B_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec C_dist.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/sec C_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/section_D.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/section_D.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/sec E_dist.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/sec E_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/Sec F1_dis.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/Sec F1_dis.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2010-11 Microdata/Sec F2_dis.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/Sec F2_dis.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/Sec C.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec C_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec D.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec D_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec E.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec E_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec F1.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec F1_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec F2.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec F2_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec G.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec G_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec H.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec H_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec I.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec I_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec J.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec J_dist.csv')

# %%
df = pd.read_spss('/content/drive/My Drive/2012-13 Microdata/sec_A.sav')
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.to_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec A_dist.csv')

# %% [markdown]
# # Province and District wise distribution

# %% [markdown]
# ##2006-2007

# %% [markdown]
# ## 2010-2011

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec B_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/province/sindh.csv')

data = province.get_group('Khyber Pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec C_dist.csv')
province = df.groupby('Province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/province/sindh.csv')

data = province.get_group('Khyber Pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec D_dist.csv')
province = df.groupby('PROVINCE')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionD/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionD/province/sindh.csv')

data = province.get_group('Khyberpakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionD/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionD/province/punjab.csv')

# %%
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionD/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec E_dist.csv')
province = df.groupby('Province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionE/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionE/province/sindh.csv')

data = province.get_group('Khyber Pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionE/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionE/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec F1_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF1/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF1/province/sindh.csv')

data = province.get_group('Khyber pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF1/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF1/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec F2_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF2/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF2/province/sindh.csv')

data = province.get_group('Khyber pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF2/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionF2/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec G_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionG/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionG/province/sindh.csv')

data = province.get_group('Khyber pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionG/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionG/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec H_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionH/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionH/province/sindh.csv')

data = province.get_group('Khyberpakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionH/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionH/province/punjab.csv')

# %%
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionH/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec I_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/province/sindh.csv')

data = province.get_group('Khyberpakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/province/punjab.csv')

# %%
data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/province/punjab.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec J_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/province/sindh.csv')

data = province.get_group('Khyber pakhtunkhwa')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/province/punjab.csv')

# %%
#asna
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec B_dist.csv')
district = df.groupby('dist')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/IslamabadB.csv')

# data = district.get_group('Attock')
# data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/AttockB.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/RawalpindiB.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/JehlumB.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ChakwalB.csv')

data = district.get_group('Sargodha')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SargodhaB.csv')

data = district.get_group('Bhakhar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BhakharB.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KhushabB.csv')

data = district.get_group('Mianwali')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MianwaliB.csv')

data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/FaisalabadB.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/JhangB.csv')

data = district.get_group('T.T.Singh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/T.T.SinghB.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ChiniotB.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/GujranwalaB.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/GujratB.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SialkotB.csv')

data = district.get_group('Hafizabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/HafizabadB.csv')

data = district.get_group('Mandi Bahuddin')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Mandi BahuddinB.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/NarowalB.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/LahoreB.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KasurB.csv')

data = district.get_group('Sheikupura')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SheikupuraB.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Nankana SahibB.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/VehariB.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MultanB.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KhanewalB.csv')

data = district.get_group('Lodhran')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/LodhranB.csv')

data = district.get_group('D.G.Khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/D.G.KhanB.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/RajanpurB.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/LayyahB.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Muzaffar GarhB.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BahawalpurB.csv')

data = district.get_group('Bahawalnagar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BahawalnagarB.csv')

data = district.get_group('RahimYar Khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/RahimYar KhanB.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SahiwalB.csv')

data = district.get_group('Pakpattan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/PakpattanB.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/OkaraB.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KhairpurB.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SukkurB.csv')

data = district.get_group('Nawabshah')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/NawabshahB.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Nowshero FerozeB.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ghotkiB.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/JaccobabadB.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KashmoreB.csv')

data = district.get_group('Shikarpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ShikarpurB.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/LarkanaB.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ShahdadkotB.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KhanewalB.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/DaduB.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/JamshoroB.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/HyderabadB.csv')

data = district.get_group('Maitari')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MaitariB.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Tando Allah YarB.csv')

data = district.get_group('Tando Muda khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Tando Muda khanB.csv')

data = district.get_group('Badin')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BadinB.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ThattaB.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SangharB.csv')

data = district.get_group('Mir Pur Khas')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Mir Pur KhasB.csv')

data = district.get_group('Umer kot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Umer kotB.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/TharparkarB.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KarachiB.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SwatB.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Upper DirB.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Lower DirB.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ChitralB.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ShanglaB.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MalakandB.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BonairB.csv')

data = district.get_group('Peshawar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/PeshawarB.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/CharsadaB.csv')

data = district.get_group('Nowshera')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/NowsheraB.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KohatB.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KarakB.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/HanguB.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/D.I.KhanB.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/TankB.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MansheraB.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/AbbottabadB.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BatagramB.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KohistanB.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/HaripurB.csv')

data = district.get_group('Bannu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BannuB.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Lakki MarwatB.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MardanB.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SwabiB.csv')

data = district.get_group('Quetta')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/QuettaB.csv')

data = district.get_group('Pashin')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/PashinB.csv')

data = district.get_group('Qillah abdullah')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Qillah abdullahB.csv')

data = district.get_group('Chagi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ChagiB.csv')

data = district.get_group('Nushki')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/NushkiB.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SibbiB.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ZiaratB.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KohluB.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Dera BugtiB.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/HarnaiB.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KalatB.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MastungB.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KhuzdarB.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/AwaranB.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KharanB.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/WashukB.csv')

data = district.get_group('Lasbilla')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/LasbillanB.csv')

data = district.get_group('Ketch/Turbat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/KetchTurbatB.csv')

data = district.get_group('Gwadar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/GwadarB.csv')

data = district.get_group('Panjgur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/PanjgurB.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/ZhobB.csv')

data = district.get_group('Lorali')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/LoraliB.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BarkhanB.csv')

data = district.get_group('Musakhel')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/MusakhelB.csv')

data = district.get_group('Qillah Saifuallh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Qillah SaifuallhB.csv')

data = district.get_group('Sherani')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/SheraniB.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/NasirabadB.csv')

data = district.get_group('Jafarabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/JafarabadB.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/Jhal MagsiB.csv')

data = district.get_group('Bolan/Kacchi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionB/district/BolanKacchiB.csv')

# %%
#asna
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec C_dist.csv')
district = df.groupby('District')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/IslamabadC.csv')

# data = district.get_group('Attock')
# data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/AttockC.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/RawalpindiC.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/JehlumC.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/ChakwalC.csv')

data = district.get_group('Sargodha')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/SargodhaC.csv')

data = district.get_group('Bhakhar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/BhakharC.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/KhushabC.csv')

data = district.get_group('Mianwali')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/MianwaliC.csv')

data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/FaisalabadC.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/JhangC.csv')

data = district.get_group('T.T.Singh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/T.T.SinghC.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/ChiniotC.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/GujranwalaC.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/GujratC.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/SialkotC.csv')

data = district.get_group('Hafizabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/HafizabadC.csv')

data = district.get_group('Mandi Bahuddin')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/Mandi BahuddinC.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/NarowalC.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/LahoreC.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/KasurC.csv')

data = district.get_group('Sheikupura')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/SheikupuraC.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/Nankana SahibC.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/VehariC.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/MultanC.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/KhanewalC.csv')

data = district.get_group('Lodhran')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/LodhranC.csv')

data = district.get_group('D.G.Khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district/D.G.KhanC.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionC/district
csv')

data = district.get_group('Lasbilla')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/LasbillanI.csv')

data = district.get_group('Ketch/Turbat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/KetchTurbatI.csv')

data = district.get_group('Gwadar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/GwadarI.csv')

data = district.get_group('Panjgur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/PanjgurI.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/ZhobI.csv')

data = district.get_group('Lorali')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/LoraliI.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/BarkhanI.csv')

data = district.get_group('Musakhel')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/MusakhelI.csv')

data = district.get_group('Qillah Saifuallh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/Qillah SaifuallhI.csv')

data = district.get_group('Sherani')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/SheraniI.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/NasirabadI.csv')

data = district.get_group('Jafarabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/JafarabadI.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/Jhal MagsiI.csv')

data = district.get_group('Bolan/Kacchi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionI/district/BolanKacchiI.csv')

# %%
#asna
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2010-2011 /sec J_dist.csv')
district = df.groupby('district')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/IslamabadJ.csv')

# data = district.get_group('Attock')
# data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/AttockJ.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/RawalpindiJ.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/JehlumJ.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ChakwalJ.csv')

data = district.get_group('Sargodha')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SargodhaJ.csv')

data = district.get_group('Bhakhar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BhakharJ.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KhushabJ.csv')

data = district.get_group('Mianwali')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MianwaliJ.csv')

data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/FaisalabadJ.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/JhangJ.csv')

data = district.get_group('T.T.Singh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/T.T.SinghJ.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ChiniotJ.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/GujranwalaJ.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/GujratJ.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SialkotJ.csv')

data = district.get_group('Hafizabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/HafizabadJ.csv')

data = district.get_group('Mandi Bahuddin')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Mandi BahuddinJ.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/NarowalJ.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/LahoreJ.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KasurJ.csv')

data = district.get_group('Sheikupura')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SheikupuraJ.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Nankana SahibJ.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/VehariJ.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MultanJ.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KhanewalJ.csv')

data = district.get_group('Lodhran')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/LodhranJ.csv')

data = district.get_group('D.G.Khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/D.G.KhanJ.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/RajanpurJ.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/LayyahJ.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Muzaffar GarhJ.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BahawalpurJ.csv')

data = district.get_group('Bahawalnagar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BahawalnagarJ.csv')

data = district.get_group('RahimYar Khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/RahimYar KhanJ.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SahiwalJ.csv')

data = district.get_group('Pakpattan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/PakpattanJ.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/OkaraJ.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KhairpurJ.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SukkurJ.csv')

data = district.get_group('Nawabshah')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/NawabshahJ.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Nowshero FerozeJ.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/GhotkiJ.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/JaccobabadJ.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KashmoreJ.csv')

data = district.get_group('Shikarpur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ShikarpurJ.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/LarkanaJ.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ShahdadkotJ.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KhanewalJ.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/DaduJ.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/JamshoroJ.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/HyderabadJ.csv')

data = district.get_group('Maitari')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MaitariJ.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Tando Allah YarJ.csv')

data = district.get_group('Tando Muda khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Tando Muda khanJ.csv')

data = district.get_group('Badin')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BadinJ.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ThattaJ.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SangharJ.csv')

data = district.get_group('Mir Pur Khas')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Mir Pur KhasJ.csv')

data = district.get_group('Umer Kot')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Umer kotJ.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/TharparkarJ.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KarachiJ.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SwatJ.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Upper DirJ.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Lower DirJ.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ChitralJ.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ShanglaJ.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MalakandJ.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BonairJ.csv')

data = district.get_group('Peshawar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/PeshawarJ.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/CharsadaJ.csv')

data = district.get_group('Nowshera')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/NowsheraJ.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KohatJ.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KarakJ.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/HanguJ.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/D.I.KhanJ.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/TankJ.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MansheraJ.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/AbbottabadJ.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BatagramJ.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KohistanJ.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/HaripurJ.csv')

data = district.get_group('Bannu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BannuJ.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Lakki MarwatJ.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MardanJ.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SwabiJ.csv')

data = district.get_group('Quetta')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/QuettaJ.csv')

data = district.get_group('Pashin')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/PashinJ.csv')

data = district.get_group('Qillah abdullah')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Qillah abdullahJ.csv')

data = district.get_group('Chagi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ChagiJ.csv')

data = district.get_group('Nushki')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/NushkiJ.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SibbiJ.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ZiaratJ.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KohluJ.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Dera BugtiJ.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/HarnaiJ.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KalatJ.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MastungJ.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KhuzdarJ.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/AwaranJ.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KharanJ.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/WashukJ.csv')

data = district.get_group('Lasbilla')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/LasbillanJ.csv')

data = district.get_group('Ketch/Turbat')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/KetchTurbatJ.csv')

data = district.get_group('Gwadar')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/GwadarJ.csv')

data = district.get_group('Panjgur')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/PanjgurJ.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/ZhobJ.csv')

data = district.get_group('Lorali')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/LoraliJ.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BarkhanJ.csv')

data = district.get_group('Musakhel')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/MusakhelJ.csv')

data = district.get_group('Qillah Saifuallh')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Qillah SaifuallhJ.csv')

data = district.get_group('Sherani')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/SheraniJ.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/NasirabadJ.csv')

data = district.get_group('Jafarabad')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/JafarabadJ.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/Jhal MagsiJ.csv')

data = district.get_group('Bolan/Kacchi')
data.to_csv('/content/drive/My Drive/csv files/2010-11/sectionJ/district/BolanKacchiJ.csv')

# %% [markdown]
# ##2012-2013

# %%
#asna

df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec A_dist.csv')
province = df.groupby('Province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/province/sindh.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/province/punjab.csv')

data = province.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/province/islamabad.csv')

#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec C_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionC/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionC/province/sindh.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionC/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionC/province/punjab.csv')

data = province.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionC/province/islamabad.csv')

#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec D_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/province/sindh.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/province/punjab.csv')

data = province.get_group('Ïslamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/province/islamabad.csv')

#####################################################################################################
#SECTION E
#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec F1_dist.csv')
province = df.groupby('province')

data.province.unique()
data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/province/sindh.csv')

# data = province.get_group('KPK')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/province/punjab.csv')

data = province.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/province/islamabad.csv')

#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec F2_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF2/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF2/province/sindh.csv')

# data = province.get_group('KPK')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF2/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF2/province/punjab.csv')

data = province.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF2/province/islamabad.csv')

#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec G_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionG/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionG/province/sindh.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionG/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionG/province/punjab.csv')

data = province.get_group('Ïslamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionG/province/islamabad.csv')

#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec H_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/province/sindh.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/province/punjab.csv')

data = province.get_group('Ïslamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/province/islamabad.csv')

#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec I_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/province/sindh.csv')

data = province.get_group('KPK')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/province/punjab.csv')

data = province.get_group('Ïslamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/province/islamabad.csv')

#####################################################################################################
df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec J_dist.csv')
province = df.groupby('province')

data = province.get_group('Balochistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/province/balochistan.csv')

data = province.get_group('Sindh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/province/sindh.csv')

# data = province.get_group('KPK')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/province/kpk.csv')

data = province.get_group('Punjab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/province/punjab.csv')

data = province.get_group('islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/province/islamabad.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#asna

#sectionA

df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec A_dist.csv')
district = df.groupby('district')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/IslamabadA.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/BhawanagarA.csv')


data = district.get_group('Ättock')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/AttockA.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/RawalpindiA.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/JehlumA.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ChakwalA.csv')

data = district.get_group('Sarghodha')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/SargodhaA.csv')

data = district.get_group('Bhakar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/BhakharA.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KhushabA.csv')

data = district.get_group('M ianwali')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/MianwaliA.csv')

data = district.get_group('Mitiari')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/MitiariA.csv')


data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/FaisalabadA.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/JhangA.csv')

data = district.get_group('T.T Singh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/T.T.SinghA.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ChiniotA.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/GujranwalaA.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/GujratA.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/SialkotA.csv')

data = district.get_group('Hafaizabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/HafaizabadA.csv')

data = district.get_group('Mandi Bahauddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Mandi BahauddinA.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/NarowalA.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/LahoreA.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KasurA.csv')

data = district.get_group('Sheikhupura')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/SheikhupuraA.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Nankana SahibA.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/VehariA.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/MultanA.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KhanewalA.csv')

data = district.get_group('Lodhrean')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/LodhranA.csv')

data = district.get_group('D.G Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/D.G.KhanA.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/RajanpurA.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/LayyahA.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Muzaffar GarhA.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/BahawalpurA.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/BhawanagarA.csv')

data = district.get_group('Rahim Yar Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/RahimYar KhanA.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/SahiwalA.csv')

data = district.get_group('Pakpatan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/PakpatanA.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/OkaraA.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KhairpurA.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/SukkurA.csv')

data = district.get_group('Nawabsha')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/NawabshahA.csv')

data = district.get_group('Nauski')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/NauskiA.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Nowshero FerozeA.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ghotkiA.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/JaccobabadA.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KashmoreA.csv')

data = district.get_group('Shiokarpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ShikarpurA.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/LarkanaA.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ShahdadkotA.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KhanewalA.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/DaduA.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/JamshoroA.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/HyderabadA.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Tando Allah YarA.csv')

data = district.get_group('Tando Mohd Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Tando Mohd KhanA.csv')

data = district.get_group('Baddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/BadinA.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ThattaA.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/SangharA.csv')

data = district.get_group('Mir pur khas')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Mir Pur KhasA.csv')

data = district.get_group('Ümer Kot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Umer kotA.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/TharparkarA.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KarachiA.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/SwatA.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Upper DirA.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/Lower DirA.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ChitralA.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/ShanglaA.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/MalakandA.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/BonairA.csv')

data = district.get_group('peshawar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/PeshawarA.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/CharsadaA.csv')

data = district.get_group('Nowsehra')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/NowsheraA.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KohatA.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/KarakA.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/HanguA.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/D.I.KhanA.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/TankA.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionA/district/
csv')

data = district.get_group('Mandi Bahauddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Mandi BahauddinD.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/NarowalD.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/LahoreD.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KasurD.csv')

data = district.get_group('Sheikhupura')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SheikhupuraD.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Nankana SahibD.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/VehariD.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/MultanD.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KhanewalD.csv')

data = district.get_group('Lodhrean')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/LodhranD.csv')

data = district.get_group('D.G Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/D.G.KhanD.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/RajanpurD.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/LayyahD.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Muzaffar GarhD.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BahawalpurD.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BhawanagarD.csv')

data = district.get_group('Rahim Yar Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/RahimYar KhanD.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SahiwalD.csv')

data = district.get_group('Pakpatan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/PakpatanD.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/OkaraD.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KhairpurD.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SukkurD.csv')

data = district.get_group('Nawabsha')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/NawabshahD.csv')

data = district.get_group('Nauski')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/NauskiD.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Nowshero FerozeD.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ghotkiD.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/JaccobabadD.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KashmoreD.csv')

data = district.get_group('Shiokarpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ShikarpurD.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/LarkanaD.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ShahdadkotD.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KhanewalD.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/DaduD.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/JamshoroD.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/HyderabadD.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Tando Allah YarD.csv')

data = district.get_group('Tando Mohd Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Tando Mohd KhanD.csv')

data = district.get_group('Baddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BadinD.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ThattaD.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SangharD.csv')

data = district.get_group('Mir pur khas')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Mir Pur KhasD.csv')

data = district.get_group('Ümer Kot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Umer kotD.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/TharparkarD.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KarachiD.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SwatD.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Upper DirD.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Lower DirD.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ChitralD.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ShanglaD.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/MalakandD.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BonairD.csv')

data = district.get_group('peshawar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/PeshawarD.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/CharsadaD.csv')

data = district.get_group('Nowsehra')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/NowsheraD.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KohatD.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KarakD.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/HanguD.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/D.I.KhanD.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/TankD.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/MansheraD.csv')

data = district.get_group('Torgarh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/MansheraD.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/AbbottabadD.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BatagramD.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KohistanD.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/HaripurD.csv')

data = district.get_group('bannu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BannuD.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Lakki MarwatD.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/MardanD.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SwabiD.csv')

data = district.get_group('Quetta')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/QuettaD.csv')

data = district.get_group('Pashin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/PashinD.csv')

data = district.get_group('Qilla Abdullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Qilla AbdullahD.csv')

data = district.get_group('Chaghi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ChaghiD.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SibbiD.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ZiaratD.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KohluD.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Dera BugtiD.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/HarnaiD.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KalatD.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/MastungD.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KhuzdarD.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/AwaranD.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KharanD.csv')

data = district.get_group('Keych/Turbat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/KeychTurbatD.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/WashukD.csv')

data = district.get_group('Lasbella')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/LasbellaD.csv')

data = district.get_group('Gawadar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/GawadarD.csv')

# data = district.get_group('Panjgur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/PanjgurD.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/ZhobD.csv')

data = district.get_group('Loralai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/LoralaiD.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BarkhanD.csv')

data = district.get_group('Musa Khel')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Musa KhelD.csv')

data = district.get_group('Qilla Saifullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Qilla SaifullahD.csv')

data = district.get_group('Sheani')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/SheraniD.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/NasirabadD.csv')

data = district.get_group('Jaffarabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/JafarabadD.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/Jhal MagsiD.csv')

data = district.get_group('Bolan/Kachhi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionD/district/BolanKachhiD.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#asna


#sectionF1

df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec F1_dist.csv')
district = df.groupby('dist')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/IslamabadF1.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BhawanagarF1.csv')

# data = district.get_group('Attock')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/AttockF1.csv')

# data = district.get_group('Rawalpindi')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/RawalpindiF1.csv')

# data = district.get_group('Jehlum')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/JehlumF1.csv')

# data = district.get_group('Chakwal')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ChakwalF1.csv')

# data = district.get_group('Sarghodha')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SargodhaF1.csv')

# data = district.get_group('Bhakar')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BhakharF1.csv')

# data = district.get_group('Khushab')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KhushabF1.csv')

# data = district.get_group('Mianwali')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MianwaliF1.csv')

# data = district.get_group('Mitiari')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MitiariF1.csv')

data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/FaisalabadF1.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/JhangF1.csv')

data = district.get_group('T.T Singh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/T.T.SinghF1.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ChiniotF1.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/GujranwalaF1.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/GujratF1.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SialkotF1.csv')

data = district.get_group('Hafaizabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/HafaizabadF1.csv')

data = district.get_group('Mandi Bahauddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Mandi BahauddinF1.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/NarowalF1.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/LahoreF1.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KasurF1.csv')

data = district.get_group('Sheikhupura')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SheikhupuraF1.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Nankana SahibF1.csv')

# data = district.get_group('Vehari')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/VehariF1.csv')

# data = district.get_group('Multan')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MultanF1.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KhanewalF1.csv')

data = district.get_group('Lodhrean')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/LodhranF1.csv')

data = district.get_group('D.G Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/D.G.KhanF1.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/RajanpurF1.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/LayyahF1.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Muzaffar GarhF1.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BahawalpurF1.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BhawanagarF1.csv')

data = district.get_group('Rahim Yar Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/RahimYar KhanF1.csv')

# data = district.get_group('Sahiwal')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SahiwalF1.csv')

# data = district.get_group('Pakpatan')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/PakpatanF1.csv')

# data = district.get_group('Okara')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/OkaraF1.csv')

# data = district.get_group('Khairpur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KhairpurF1.csv')

# data = district.get_group('Sukkur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SukkurF1.csv')

# data = district.get_group('Nawabsha')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/NawabshahF1.csv')

# data = district.get_group('Nauski')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/NauskiF1.csv')

# data = district.get_group('Nowshero Feroze')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Nowshero FerozeF1.csv')

# data = district.get_group('Ghotki')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ghotkiF1.csv')

# data = district.get_group('Jaccobabad')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/JaccobabadF1.csv')

# data = district.get_group('Kashmore')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KashmoreF1.csv')

# data = district.get_group('Shiokarpur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ShikarpurF1.csv')

# data = district.get_group('Larkana')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/LarkanaF1.csv')

# data = district.get_group('Shahdadkot')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ShahdadkotF1.csv')

# data = district.get_group('Khanewal')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KhanewalF1.csv')

# data = district.get_group('Dadu')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/DaduF1.csv')

# data = district.get_group('Jamshoro')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/JamshoroF1.csv')

# data = district.get_group('Hyderabad')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/HyderabadF1.csv')

# data = district.get_group('Tando Allah Yar')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Tando Allah YarF1.csv')

# data = district.get_group('Tando Mohd Khan')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Tando Mohd KhanF1.csv')

# data = district.get_group('Baddin')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BadinF1.csv')

# data = district.get_group('Thatta')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ThattaF1.csv')

# data = district.get_group('Sanghar')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SangharF1.csv')

# data = district.get_group('Mir pur khas')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Mir Pur KhasF1.csv')

# data = district.get_group('Ümer Kot')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Umer kotF1.csv')

# data = district.get_group('Tharparkar')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/TharparkarF1.csv')

# data = district.get_group('Karachi')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KarachiF1.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SwatF1.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Upper DirF1.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Lower DirF1.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ChitralF1.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ShanglaF1.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MalakandF1.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BonairF1.csv')

data = district.get_group('peshawar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/PeshawarF1.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/CharsadaF1.csv')

data = district.get_group('Nowsehra')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/NowsheraF1.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KohatF1.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KarakF1.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/HanguF1.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/D.I.KhanF1.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/TankF1.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MansheraF1.csv')

data = district.get_group('Torgarh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MansheraF1.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/AbbottabadF1.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BatagramF1.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KohistanF1.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/HaripurF1.csv')

data = district.get_group('bannu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BannuF1.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Lakki MarwatF1.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MardanF1.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SwabiF1.csv')

# data = district.get_group('Quetta')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/QuettaF1.csv')

# data = district.get_group('Pashin')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/PashinF1.csv')

# data = district.get_group('Qilla Abdullah')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Qilla AbdullahF1.csv')

# data = district.get_group('Chaghi')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ChaghiF1.csv')

# data = district.get_group('Sibbi')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/SibbiF1.csv')

# data = district.get_group('Ziarat')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ZiaratF1.csv')

# data = district.get_group('Kohlu')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KohluF1.csv')

# data = district.get_group('Dera Bugti')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Dera BugtiF1.csv')

# data = district.get_group('Harnai')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/HarnaiF1.csv')

# data = district.get_group('Kalat')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KalatF1.csv')

# data = district.get_group('Mastung')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/MastungF1.csv')

# data = district.get_group('Khuzdar')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KhuzdarF1.csv')

# data = district.get_group('Awaran')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/AwaranF1.csv')

# data = district.get_group('Kharan')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KharanF1.csv')

# data = district.get_group('Keych/Turbat')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/KeychTurbatF1.csv')

# data = district.get_group('Washuk')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/WashukF1.csv')

# data = district.get_group('Lasbella')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/LasbellaF1.csv')

# data = district.get_group('Gawadar')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/GawadarF1.csv')

# data = district.get_group('Panjgur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/PanjgurF1.csv')

# data = district.get_group('Zhob')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/ZhobF1.csv')

# data = district.get_group('Loralai')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/LoralaiF1.csv')

# data = district.get_group('Barkhan')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/BarkhanF1.csv')

# data = district.get_group('Musa Khel')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Musa KhelF1.csv')

# data = district.get_group('Qilla Saifullah')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district/Qilla SaifullahF1.csv')

# data = district.get_group('Sheani')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionF1/district
csv')

data = district.get_group('Qilla Abdullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/Qilla AbdullahH.csv')

data = district.get_group('Chaghi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/ChaghiH.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/SibbiH.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/ZiaratH.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/KohluH.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/Dera BugtiH.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/HarnaiH.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/KalatH.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/MastungH.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/KhuzdarH.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/AwaranH.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/KharanH.csv')

data = district.get_group('Keych/Turbat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/KeychTurbatH.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/WashukH.csv')

data = district.get_group('Lasbella')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/LasbellaH.csv')

data = district.get_group('Gawadar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/GawadarH.csv')

# data = district.get_group('Panjgur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/PanjgurH.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/ZhobH.csv')

data = district.get_group('Loralai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/LoralaiH.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/BarkhanH.csv')

data = district.get_group('Musa Khel')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/Musa KhelH.csv')

data = district.get_group('Qilla Saifullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/Qilla SaifullahH.csv')

data = district.get_group('Sheani')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/SheraniH.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/NasirabadH.csv')

data = district.get_group('Jaffarabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/JafarabadH.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/Jhal MagsiH.csv')

data = district.get_group('Bolan/Kachhi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionH/district/BolanKachhiH.csv')

# %%
#asna


#sectionI

df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec I_dist.csv')
district = df.groupby('district')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/IslamabadI.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BhawanagarI.csv')

data = district.get_group('Ättock')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/AttockI.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/RawalpindiI.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/JehlumI.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ChakwalI.csv')

data = district.get_group('Sarghodha')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SargodhaI.csv')

data = district.get_group('Bhakar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BhakharI.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KhushabI.csv')

data = district.get_group('M ianwali')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MianwaliI.csv')

data = district.get_group('Mitiari')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MitiariI.csv')


data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/FaisalabadI.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/JhangI.csv')

data = district.get_group('T.T Singh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/T.T.SinghI.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ChiniotI.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/GujranwalaI.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/GujratI.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SialkotI.csv')

data = district.get_group('Hafaizabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/HafaizabadI.csv')

data = district.get_group('Mandi Bahauddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Mandi BahauddinI.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/NarowalI.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/LahoreI.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KasurI.csv')

data = district.get_group('Sheikhupura')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SheikhupuraI.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Nankana SahibI.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/VehariI.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MultanI.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KhanewalI.csv')

data = district.get_group('Lodhrean')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/LodhranI.csv')

data = district.get_group('D.G Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/D.G.KhanI.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/RajanpurI.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/LayyahI.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Muzaffar GarhI.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BahawalpurI.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BhawanagarI.csv')

data = district.get_group('Rahim Yar Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/RahimYar KhanI.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SahiwalI.csv')

data = district.get_group('Pakpatan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/PakpatanI.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/OkaraI.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KhairpurI.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SukkurI.csv')

data = district.get_group('Nawabsha')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/NawabshahI.csv')

data = district.get_group('Nauski')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/NauskiI.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Nowshero FerozeI.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ghotkiI.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/JaccobabadI.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KashmoreI.csv')

data = district.get_group('Shiokarpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ShikarpurI.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/LarkanaI.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ShahdadkotI.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KhanewalI.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/DaduI.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/JamshoroI.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/HyderabadI.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Tando Allah YarI.csv')

data = district.get_group('Tando Mohd Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Tando Mohd KhanI.csv')

data = district.get_group('Baddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BadinI.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ThattaI.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SangharI.csv')

data = district.get_group('Mir pur khas')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Mir Pur KhasI.csv')

data = district.get_group('Ümer Kot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Umer kotI.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/TharparkarI.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KarachiI.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SwatI.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Upper DirI.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Lower DirI.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ChitralI.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ShanglaI.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MalakandI.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BonairI.csv')

data = district.get_group('peshawar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/PeshawarI.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/CharsadaI.csv')

data = district.get_group('Nowsehra')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/NowsheraI.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KohatI.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KarakI.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/HanguI.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/D.I.KhanI.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/TankI.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MansheraI.csv')

data = district.get_group('Torgarh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MansheraI.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/AbbottabadI.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BatagramI.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KohistanI.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/HaripurI.csv')

data = district.get_group('bannu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BannuI.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Lakki MarwatI.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MardanI.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SwabiI.csv')

data = district.get_group('Quetta')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/QuettaI.csv')

data = district.get_group('Pashin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/PashinI.csv')

data = district.get_group('Qilla Abdullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Qilla AbdullahI.csv')

data = district.get_group('Chaghi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ChaghiI.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SibbiI.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ZiaratI.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KohluI.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Dera BugtiI.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/HarnaiI.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KalatI.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/MastungI.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KhuzdarI.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/AwaranI.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KharanI.csv')

data = district.get_group('Keych/Turbat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/KeychTurbatI.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/WashukI.csv')

data = district.get_group('Lasbella')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/LasbellaI.csv')

data = district.get_group('Gawadar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/GawadarI.csv')

# data = district.get_group('Panjgur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/PanjgurI.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/ZhobI.csv')

data = district.get_group('Loralai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/LoralaiI.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BarkhanI.csv')

data = district.get_group('Musa Khel')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Musa KhelI.csv')

data = district.get_group('Qilla Saifullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Qilla SaifullahI.csv')

data = district.get_group('Sheani')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/SheraniI.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/NasirabadI.csv')

data = district.get_group('Jaffarabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/JafarabadI.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/Jhal MagsiI.csv')

data = district.get_group('Bolan/Kachhi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionI/district/BolanKachhiI.csv')

# %%
#asna


#sectionJ

df = pd.read_csv('/content/drive/My Drive/files with white spaces remove/2012-2013/sec J_dist.csv')
district = df.groupby('dist')

data = district.get_group('Islamabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/IslamabadJ.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BhawanagarJ.csv')

data = district.get_group('Ättock')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/AttockJ.csv')

data = district.get_group('Rawalpindi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/RawalpindiJ.csv')

data = district.get_group('Jehlum')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/JehlumJ.csv')

data = district.get_group('Chakwal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ChakwalJ.csv')

data = district.get_group('Sarghodha')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SargodhaJ.csv')

data = district.get_group('Bhakar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BhakharJ.csv')

data = district.get_group('Khushab')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KhushabJ.csv')

data = district.get_group('M ianwali')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MianwaliJ.csv')

data = district.get_group('Mitiari')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MitiariJ.csv')


data = district.get_group('Faisalabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/FaisalabadJ.csv')

data = district.get_group('Jhang')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/JhangJ.csv')

data = district.get_group('T.T Singh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/T.T.SinghJ.csv')

data = district.get_group('Chiniot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ChiniotJ.csv')

data = district.get_group('Gujranwala')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/GujranwalaJ.csv')

data = district.get_group('Gujrat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/GujratJ.csv')

data = district.get_group('Sialkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SialkotJ.csv')

data = district.get_group('Hafaizabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/HafaizabadJ.csv')

data = district.get_group('Mandi Bahauddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Mandi BahauddinJ.csv')

data = district.get_group('Narowal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/NarowalJ.csv')

data = district.get_group('Lahore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/LahoreJ.csv')

data = district.get_group('Kasur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KasurJ.csv')

data = district.get_group('Sheikhupura')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SheikhupuraJ.csv')

data = district.get_group('Nankana Sahib')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Nankana SahibJ.csv')

data = district.get_group('Vehari')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/VehariJ.csv')

data = district.get_group('Multan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MultanJ.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KhanewalJ.csv')

data = district.get_group('Lodhrean')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/LodhranJ.csv')

data = district.get_group('D.G Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/D.G.KhanJ.csv')

data = district.get_group('Rajanpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/RajanpurJ.csv')

data = district.get_group('Layyah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/LayyahJ.csv')

data = district.get_group('Muzaffar Garh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Muzaffar GarhJ.csv')

data = district.get_group('Bahawalpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BahawalpurJ.csv')

data = district.get_group('Bhawanagar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BhawanagarJ.csv')

data = district.get_group('Rahim Yar Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/RahimYar KhanJ.csv')

data = district.get_group('Sahiwal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SahiwalJ.csv')

data = district.get_group('Pakpatan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/PakpatanJ.csv')

data = district.get_group('Okara')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/OkaraJ.csv')

data = district.get_group('Khairpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KhairpurJ.csv')

data = district.get_group('Sukkur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SukkurJ.csv')

data = district.get_group('Nawabsha')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/NawabshahJ.csv')

data = district.get_group('Nauski')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/NauskiJ.csv')

data = district.get_group('Nowshero Feroze')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Nowshero FerozeJ.csv')

data = district.get_group('Ghotki')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ghotkiJ.csv')

data = district.get_group('Jaccobabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/JaccobabadJ.csv')

data = district.get_group('Kashmore')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KashmoreJ.csv')

data = district.get_group('Shiokarpur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ShikarpurJ.csv')

data = district.get_group('Larkana')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/LarkanaJ.csv')

data = district.get_group('Shahdadkot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ShahdadkotJ.csv')

data = district.get_group('Khanewal')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KhanewalJ.csv')

data = district.get_group('Dadu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/DaduJ.csv')

data = district.get_group('Jamshoro')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/JamshoroJ.csv')

data = district.get_group('Hyderabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/HyderabadJ.csv')

data = district.get_group('Tando Allah Yar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Tando Allah YarJ.csv')

data = district.get_group('Tando Mohd Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Tando Mohd KhanJ.csv')

data = district.get_group('Baddin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BadinJ.csv')

data = district.get_group('Thatta')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ThattaJ.csv')

data = district.get_group('Sanghar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SangharJ.csv')

data = district.get_group('Mir pur khas')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Mir Pur KhasJ.csv')

data = district.get_group('Ümer Kot')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Umer kotJ.csv')

data = district.get_group('Tharparkar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/TharparkarJ.csv')

data = district.get_group('Karachi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KarachiJ.csv')

data = district.get_group('Swat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SwatJ.csv')

data = district.get_group('Upper Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Upper DirJ.csv')

data = district.get_group('Lower Dir')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Lower DirJ.csv')

data = district.get_group('Chitral')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ChitralJ.csv')

data = district.get_group('Shangla')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ShanglaJ.csv')

data = district.get_group('Malakand')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MalakandJ.csv')

data = district.get_group('Bonair')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BonairJ.csv')

data = district.get_group('peshawar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/PeshawarJ.csv')

data = district.get_group('Charsada')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/CharsadaJ.csv')

data = district.get_group('Nowsehra')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/NowsheraJ.csv')

data = district.get_group('Kohat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KohatJ.csv')

data = district.get_group('Karak')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KarakJ.csv')

data = district.get_group('Hangu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/HanguJ.csv')

data = district.get_group('D.I.Khan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/D.I.KhanJ.csv')

data = district.get_group('Tank')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/TankJ.csv')

data = district.get_group('Manshera')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MansheraJ.csv')

data = district.get_group('Torgarh')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MansheraJ.csv')

data = district.get_group('Abbottabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/AbbottabadJ.csv')

data = district.get_group('Batagram')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BatagramJ.csv')

data = district.get_group('Kohistan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KohistanJ.csv')

data = district.get_group('Haripur')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/HaripurJ.csv')

data = district.get_group('bannu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BannuJ.csv')

data = district.get_group('Lakki Marwat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Lakki MarwatJ.csv')

data = district.get_group('Mardan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MardanJ.csv')

data = district.get_group('Swabi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SwabiJ.csv')

data = district.get_group('Quetta"')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/QuettaJ.csv')

data = district.get_group('Pashin')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/PashinJ.csv')

data = district.get_group('Qilla Abdullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Qilla AbdullahJ.csv')

data = district.get_group('Chaghi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ChaghiJ.csv')

data = district.get_group('Sibbi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SibbiJ.csv')

data = district.get_group('Ziarat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ZiaratJ.csv')

data = district.get_group('Kohlu')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KohluJ.csv')

data = district.get_group('Dera Bugti')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Dera BugtiJ.csv')

data = district.get_group('Harnai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/HarnaiJ.csv')

data = district.get_group('Kalat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KalatJ.csv')

data = district.get_group('Mastung')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/MastungJ.csv')

data = district.get_group('Khuzdar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KhuzdarJ.csv')

data = district.get_group('Awaran')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/AwaranJ.csv')

data = district.get_group('Kharan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KharanJ.csv')

data = district.get_group('Keych/Turbat')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/KeychTurbatJ.csv')

data = district.get_group('Washuk')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/WashukJ.csv')

data = district.get_group('Lasbella')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/LasbellaJ.csv')

data = district.get_group('Gawadar')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/GawadarJ.csv')

# data = district.get_group('Panjgur')
# data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/PanjgurJ.csv')

data = district.get_group('Zhob')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/ZhobJ.csv')

data = district.get_group('Loralai')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/LoralaiJ.csv')

data = district.get_group('Barkhan')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BarkhanJ.csv')

data = district.get_group('Musa Khel')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Musa KhelJ.csv')

data = district.get_group('Qilla Saifullah')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Qilla SaifullahJ.csv')

data = district.get_group('Sheani')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/SheraniJ.csv')

data = district.get_group('Nasirabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/NasirabadJ.csv')

data = district.get_group('Jaffarabad')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/JafarabadJ.csv')

data = district.get_group('Jhal Magsi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/Jhal MagsiJ.csv')

data = district.get_group('Bolan/Kachhi')
data.to_csv('/content/drive/My Drive/csv files/2012-13/sectionJ/district/BolanKachhiJ.csv')

# %% [markdown]
# #Check Data Type

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/Sec F1_dis.csv')

# %%
datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# province       object
# district       object
# region         object
# psu           float64
# section        object
# q1to10         object
# sf1col1        object
# sf1col2       float64
# sf1col3        object
# sf1col4       float64
# sf1col5       float64
# dtype: object

# %%
datatype.sf1col4.unique()
# Out:
# array([nan,  1.,  3.,  2.,  6.])

# %% [markdown]
# datatype.column name.unique() lists the unique values in a column

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/Sec F2_dis.csv')

# %%
#zu
datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# province       object
# district       object
# region         object
# psu           float64
# section        object
# sf2q11a        object
# sf2q11b        object
# sf2q11c        object
# sf2q11d        object
# sf2q11e        object
# sf2q11f        object
# sf2q11g        object
# sf2q11h        object
# sf2q11i        object
# sf2q11j        object
# sf2q11k        object
# sf2q11l        object
# sf2q11m        object
# sf2q11n        object
# sf2q11o        object
# sf2q11p        object
# sf2q11q        object
# sf2q11r        object
# sf2q11s        object
# sf2q11t        object
# sf2q12         object
# sf2q13         object
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/Sec G_dist.csv')

# %%
#zu
datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# province       object
# district       object
# region         object
# psu           float64
# section        object
# sgq01          object
# sgq02         float64
# sgq03          object
# sgq04          object
# sgq05          object
# sgq06          object
# sgq07          object
# sgq08          object
# sgq09          object
# sgq10a1        object
# sgq10a2        object
# sgq10b1        object
# sgq10b2        object
# sgq10c1        object
# sgq10c2        object
# sgq10d1        object
# sgq10d2        object
# sgq10e1        object
# sgq10e2        object
# sgq10f1       float64
# sgq10f2        object
# sgq10g1        object
# sgq10g2        object
# sgq10h1        object
# sgq10h2        object
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/Sec J_dist.csv')

datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# province       object
# district       object
# region         object
# psu           float64
# section        object
# sjq01a         object
# sjq01b         object
# sjq01c         object
# sjq01d         object
# sjq02a         object
# sjq02b         object
# sjq02c         object
# sjq02d         object
# sjq03a         object
# sjq03b         object
# sjq03c         object
# sjq03d         object
# sjq04a         object
# sjq04b         object
# sjq04c         object
# sjq04d         object
# sjq05a         object
# sjq05b         object
# sjq05c         object
# sjq05d         object
# sjq06a         object
# sjq06b         object
# sjq06c         object
# sjq06d         object
# sjq07a         object
# sjq07b         object
# sjq07c         object
# sjq07d         object
# sjq08a         object
# sjq08b         object
# sjq08c         object
# sjq08d         object
# sjq09a         object
# sjq09b        float64
# ...

# %%
datatype.sjq09b.unique()
# Out:
# array([nan])

# %%
datatype['sjq09b'] = datatype.sjq09b.astype(object)

# %% [markdown]
# converts float to object

# %%
datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# province       object
# district       object
# region         object
# psu           float64
# section        object
# sjq01a         object
# sjq01b         object
# sjq01c         object
# sjq01d         object
# sjq02a         object
# sjq02b         object
# sjq02c         object
# sjq02d         object
# sjq03a         object
# sjq03b         object
# sjq03c         object
# sjq03d         object
# sjq04a         object
# sjq04b         object
# sjq04c         object
# sjq04d         object
# sjq05a         object
# sjq05b         object
# sjq05c         object
# sjq05d         object
# sjq06a         object
# sjq06b         object
# sjq06c         object
# sjq06d         object
# sjq07a         object
# sjq07b         object
# sjq07c         object
# sjq07d         object
# sjq08a         object
# sjq08b         object
# sjq08c         object
# sjq08d         object
# sjq09a         object
# sjq09b         object
# ...

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/Section H.csv')

datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# psu           float64
# province       object
# region         object
# district       object
# sec            object
# idc           float64
# m_id          float64
# year_c        float64
# month_c       float64
# shq03          object
# shq04          object
# shq51          object
# shq52          object
# shq53          object
# shq54          object
# shq55          object
# shq56          object
# shq57          object
# shq58          object
# shq59          object
# shq510         object
# shq511         object
# shq06          object
# shq07          object
# shq08          object
# shq09          object
# shq10         float64
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/Section I.csv')

datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# province       object
# region         object
# psu           float64
# district       object
# sec            object
# idc           float64
# siq01          object
# siq02          object
# siq03          object
# siq04          object
# siq05         float64
# siq06          object
# siq07         float64
# siq08          object
# siq09          object
# siq10          object
# siq11          object
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/sec B_dist.csv')

datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# dist           object
# province       object
# Region         object
# psu           float64
# sec            object
# idc           float64
# sbq02          object
# sbq03          object
# sbq04          object
# sbq51         float64
# sbq52         float64
# sbq53         float64
# age           float64
# sbq06          object
# sbq07         float64
# sbq08         float64
# sbq09         float64
# sbq10          object
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/sec C_dist.csv')

datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# District       object
# Province       object
# Region         object
# PSU           float64
# sec            object
# idc           float64
# Scq01          object
# Scq02          object
# Scq03          object
# Scq04          object
# Scq05          object
# Scq06          object
# Scq07          object
# Scq81          object
# Scq82          object
# Scq91          object
# Scq92          object
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/section_D.csv')

datatype.dtypes
# Out:
# Unnamed: 0      int64
# HHCODE        float64
# DISTRICT       object
# PROVINCE       object
# REGION         object
# PSU           float64
# SEC            object
# IDC           float64
# SDQ01          object
# SDQ02          object
# SDQ03          object
# SDQ04         float64
# SDQ51          object
# SDQ52          object
# SDQ61          object
# SDQ62          object
# SDQ07          object
# SDQ08          object
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/files with white spaces remove/sec E_dist.csv')

datatype.dtypes
# Out:
# Unnamed: 0      int64
# hhcode        float64
# District       object
# Province       object
# Region         object
# PSU           float64
# sec            object
# idc           float64
# Seq01          object
# Seq02         float64
# Seq03          object
# Seq04         float64
# Seq05         float64
# Seq06          object
# Seq07          object
# Seq08         float64
# Seq09         float64
# Seq10         float64
# Seq11          object
# Seq12         float64
# Seq13         float64
# Seq14          object
# Seq15         float64
# Seq16          object
# Seq17         float64
# Seq18          object
# Seq19         float64
# Seq20          object
# Seq21         float64
# Seq22          object
# Seq23          object
# Seq24          object
# Seq25          object
# Seq26         float64
# dtype: object

# %%
#zu
datatype = pd.read_csv('/content/drive/My Drive/csv files/2010-11/sectionB/province/balochistan.csv')

datatype.dtypes
# Out:
# Unnamed: 0        int64
# Unnamed: 0.1      int64
# hhcode          float64
# dist             object
# province         object
# Region           object
# psu             float64
# sec              object
# idc             float64
# sbq02            object
# sbq03            object
# sbq04            object
# sbq51           float64
# sbq52           float64
# sbq53           float64
# age             float64
# sbq06            object
# sbq07           float64
# sbq08           float64
# sbq09           float64
# sbq10            object
# dtype: object

# %% [markdown]
# # Data Visualization

# %%
data = pd.read_csv('/content/drive/My Drive/csv files/2010-11/sectionB/province/balochistan.csv')

# %%
# Printing the first 10 rows of the data frame for visualization 
data[:10]
# Out:
#    Unnamed: 0  Unnamed: 0.1        hhcode    dist  ... sbq07 sbq08  sbq09 sbq10
# 0      420365        420365  4.011100e+10  Quetta  ...   2.0  99.0   99.0   Yes
# 1      420366        420366  4.011100e+10  Quetta  ...   1.0  99.0   99.0   Yes
# 2      420367        420367  4.011100e+10  Quetta  ...   NaN   1.0    2.0   Yes
# 3      420368        420368  4.011100e+10  Quetta  ...   NaN   1.0    2.0   Yes
# 4      420369        420369  4.011100e+10  Quetta  ...   NaN   1.0    2.0   Yes
# 5      420370        420370  4.011100e+10  Quetta  ...   2.0  99.0   99.0   Yes
# 6      420371        420371  4.011100e+10  Quetta  ...   1.0  99.0   99.0   Yes
# 7      420372        420372  4.011100e+10  Quetta  ...   NaN   1.0    2.0   Yes
# 8      420373        420373  4.011100e+10  Quetta  ...   NaN   1.0    2.0   Yes
# 9      420374        420374  4.011100e+10  Quetta  ...   NaN   1.0    2.0   Yes
#
# [10 rows x 21 columns]

# %%
# To find the correlation among 
# the columns using pearson method 
corr = data.corr(method='pearson')
corr.head()
# Out:
#               Unnamed: 0  Unnamed: 0.1    hhcode  ...     sbq07     sbq08     sbq09
# Unnamed: 0      1.000000      1.000000  0.999246  ... -0.076575 -0.021167 -0.010912
# Unnamed: 0.1    1.000000      1.000000  0.999246  ... -0.076575 -0.021167 -0.010912
# hhcode          0.999246      0.999246  1.000000  ... -0.077478 -0.021837 -0.011555
# psu             0.999246      0.999246  1.000000  ... -0.077478 -0.021837 -0.011555
# idc            -0.003461     -0.003461 -0.002288  ...  0.309317 -0.481031 -0.470851
#
# [5 rows x 12 columns]

# %%
import seaborn as sns
sns.heatmap(corr)

# %%
labels = {
    'hhcode': 'hhcode', 
    'dist': 'District', 
    'Region': 'Region', 
    'psu': 'Primary Sampling Unit',
    'sec': 'Section',
    'idc': 'Number of members',
    'sbq02': 'Relationship',
    'sbq03': 'Gender',
    'sbq04': 'Presence', 
    'sbq51': 'Year of Birth',
    'sbq52': 'Month of Birth',
    'sbq53': 'Date of Birth', 
    'age': 'Age', 
    'sbq06': 'Status',
    'sbq07': 'idc',
    'sbq08': 'Father idc',
    'sbq09': 'Mother idc',
    'sbq10': 'Yes/No'

}

corr = corr.rename(labels)

# Colors
cmap = sns.diverging_palette(240, 10, as_cmap=True)

sns.heatmap(corr, mask=mask, linewidths=.5, cmap=cmap, center=0)

# %%
status = data["sbq06"]
ages = data["age"]

# %%
x=[]
y=[]

# %%
x=list(status)
y=list(ages)

# %%
plt.scatter(x,y)
plt.xlabel('status ->')
plt.ylabel('ages ->')
plt.title('Data')
plt.show()

# %%
#usman
data = pd.read_csv("/content/drive/My Drive/csv files/2010-11/sectionB/province/punjab.csv")

data = data.drop(columns=['Unnamed: 0'])

# %%
#usman
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np


def heatmap(x, y, **kwargs):
    if 'color' in kwargs:
        color = kwargs['color']
    else:
        color = [1]*len(x)

    if 'palette' in kwargs:
        palette = kwargs['palette']
        n_colors = len(palette)
    else:
        n_colors = 256 # Use 256 colors for the diverging color palette
        palette = sns.color_palette("Blues", n_colors) 

    if 'color_range' in kwargs:
        color_min, color_max = kwargs['color_range']
    else:
        color_min, color_max = min(color), max(color) # Range of values that will be mapped to the palette, i.e. min and max possible correlation

    def value_to_color(val):
        if color_min == color_max:
            return palette[-1]
        else:
            val_position = float((val - color_min)) / (color_max - color_min) # position of value in the input range, relative to the length of the input range
            val_position = min(max(val_position, 0), 1) # bound the position betwen 0 and 1
            ind = int(val_position * (n_colors - 1)) # target index in the color palette
            return palette[ind]

    if 'size' in kwargs:
        size = kwargs['size']
    else:
        size = [1]*len(x)

    if 'size_range' in kwargs:
        size_min, size_max = kwargs['size_range'][0], kwargs['size_range'][1]
    else:
        size_min, size_max = min(size), max(size)

    size_scale = kwargs.get('size_scale', 500)

    def value_to_size(val):
        if size_min == size_max:
            return 1 * size_scale
        else:
            val_position = (val - size_min) * 0.99 / (size_max - size_min) + 0.01 # position of value in the input range, relative to the length of the input range
            val_position = min(max(val_position, 0), 1) # bound the position betwen 0 and 1
            return val_position * size_scale
    if 'x_order' in kwargs: 
        x_names = [t for t in kwargs['x_order']]
    else:
        x_names = [t for t in sorted(set([v for v in x]))]
    x_to_num = {p[1]:p[0] for p in enumerate(x_names)}

    if 'y_order' in kwargs: 
        y_names = [t for t in kwargs['y_order']]
    else:
        y_names = [t for t in sorted(set([v for v in y]))]
    y_to_num = {p[1]:p[0] for p in enumerate(y_names)}

    plot_grid = plt.GridSpec(1, 15, hspace=0.2, wspace=0.1) # Setup a 1x10 grid
    ax = plt.subplot(plot_grid[:,:-1]) # Use the left 14/15ths of the grid for the main plot

    marker = kwargs.get('marker', 's')

    kwargs_pass_on = {k:v for k,v in kwargs.items() if k not in [
         'color', 'palette', 'color_range', 'size', 'size_range', 'size_scale', 'marker', 'x_order', 'y_order'
    ]}

    ax.scatter(
        x=[x_to_num[v] for v in x],
        y=[y_to_num[v] for v in y],
        marker=marker,
        s=[value_to_size(v) for v in size], 
        c=[value_to_color(v) for v in color],
        **kwargs_pass_on
    )
    ax.set_xticks([v for k,v in x_to_num.items()])
    ax.set_xticklabels([k for k in x_to_num], rotation=45, horizontalalignment='right')
    ax.set_yticks([v for k,v in y_to_num.items()])
    ax.set_yticklabels([k for k in y_to_num])

    ax.grid(False, 'major')
    ax.grid(True, 'minor')
    ax.set_xticks([t + 0.5 for t in ax.get_xticks()], minor=True)
    ax.set_yticks([t + 0.5 for t in ax.get_yticks()], minor=True)

    ax.set_xlim([-0.5, max([v for v in x_to_num.values()]) + 0.5])
    ax.set_ylim([-0.5, max([v for v in y_to_num.values()]) + 0.5])
    ax.set_facecolor('#F1F1F1')

    # Add color legend on the right side of the plot
    if color_min < color_max:
        ax = plt.subplot(plot_grid[:,-1]) # Use the rightmost column of the plot

        col_x = [0]*len(palette) # Fixed x coordinate for the bars
        bar_y=np.linspace(color_min, color_max, n_colors) # y coordinates for each of the n_colors bars

        bar_height = bar_y[1] - bar_y[0]
        ax.barh(
            y=bar_y,
            width=[5]*len(palette), # Make bars 5 units wide
            left=col_x, # Make bars start at 0
            height=bar_height,
            color=palette,
            linewidth=0
        )
        ax.set_xlim(1, 2) # Bars are going from 0 to 5, so lets crop the plot somewhere in the middle
        ax.grid(False) # Hide grid
        ax.set_facecolor('white') # Make background white
        ax.set_xticks([]) # Remove horizontal ticks
        ax.set_yticks(np.linspace(min(bar_y), max(bar_y), 3)) # Show vertical ticks for min, middle and max
        ax.yaxis.tick_right() # Show vertical ticks on the right 


def corrplot(data, size_scale=500, marker='s'):
    corr = pd.melt(data.reset_index(), id_vars='index')
    corr.columns = ['x', 'y', 'value']
    heatmap(
        corr['x'], corr['y'],
        color=corr['value'], color_range=[-1, 1],
        palette=sns.diverging_palette(20, 220, n=256),
        size=corr['value'].abs(), size_range=[0,1],
        marker=marker,
        x_order=data.columns,
        y_order=data.columns[::-1],
        size_scale=size_scale
    )

# %%
#usman
# %matplotlib inline

corr = data.corr()
plt.figure(figsize=(10, 10))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
#usman
plt.figure(figsize=(10, 7))
corrplot(corr)

# %%
#remove the psu and sec as the have a strong +ve correlation
data = data.drop(columns=['psu','sec'])

# %%
data
# Out:
#         Unnamed: 0.1        hhcode       dist  ... sbq08 sbq09  sbq10
# 0                  0  1.001100e+10  Islamabad  ...  98.0  98.0    Yes
# 1                  1  1.001100e+10  Islamabad  ...  99.0  99.0    Yes
# 2                  2  1.001100e+10  Islamabad  ...   1.0   2.0    Yes
# 3                  3  1.001100e+10  Islamabad  ...   1.0   2.0    Yes
# 4                  4  1.001100e+10  Islamabad  ...   1.0   2.0    Yes
# ...              ...           ...        ...  ...   ...   ...    ...
# 201064        201064  1.362000e+10      Okara  ...   1.0   2.0    Yes
# 201065        201065  1.362000e+10      Okara  ...   1.0   2.0    Yes
# 201066        201066  1.362000e+10      Okara  ...   1.0   2.0    Yes
# 201067        201067  1.362000e+10      Okara  ...   1.0   2.0    Yes
# 201068        201068  1.362000e+10      Okara  ...   1.0   2.0    Yes
#
# [201069 rows x 18 columns]

# %%
#dealing with duplicated rows and columns
duplicateRowsDF = data[data.duplicated()]
 
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [Unnamed: 0.1, hhcode, dist, province, Region, idc, sbq02, sbq03, sbq04, sbq51, sbq52, sbq53, age, sbq06, sbq07, sbq08, sbq09, sbq10]
# Index: []

# %% [markdown]
# The data contains zero duplicate rows

# %%
#sum of 0 values 
print((data[['hhcode',	'dist',	'province',	'Region',	'idc',	'sbq02',	'sbq03',	'sbq04',	'sbq51',	'sbq52',	'sbq53',	'age',	'sbq06',	'sbq07', 'sbq08',	'sbq09',	'sbq10']] == 0).sum())
# Out:
# hhcode           0
# dist             0
# province         0
# Region           0
# idc              0
# sbq02            0
# sbq03            0
# sbq04            0
# sbq51            0
# sbq52       152369
# sbq53       159916
# age           4634
# sbq06            0
# sbq07            0
# sbq08            0
# sbq09            0
# sbq10            0
# dtype: int64

# %% [markdown]
# The following columns has missing values
#
# age
#
# sbq52
#
# sbq53

# %%
#unique values
data.dist.unique()
# Out:
# array(['Islamabad', ' Attock', 'Rawalpindi', 'Jehlum', 'Chakwal',
#        'Sargodha', 'Bhakhar', 'Khushab', 'Mianwali', 'Faisalabad',
#        'Jhang', 'T.T.Singh', 'Chiniot', 'Gujranwala', 'Gujrat', 'Sialkot',
#        'Hafizabad', 'Mandi Bahuddin', 'Narowal', 'Lahore', 'Kasur',
#        'Sheikupura', 'Nankana Sahib', 'Vehari', 'Multan', 'Khanewal',
#        'Lodhran', 'D.G.Khan', 'Rajanpur', 'Layyah', 'Muzaffar Garh',
#        'Bahawalpur', 'Bahawalnagar', 'RahimYar Khan', 'Sahiwal',
#        'Pakpattan', 'Okara'], dtype=object)

# %% [markdown]
# # Correlation

# %% [markdown]
# ##2010-2011

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec B_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec C_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec D_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec E_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec F1_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec F2_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec G_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec H_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec I_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/My Drive/weighted csv files/2010-2011/sec J_dist.csv')
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %% [markdown]
# ##2012-2013
