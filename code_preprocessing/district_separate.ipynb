# %%
import pandas as pd

# %%
data = pd.read_csv('../../raw_data/SEC_B_2015.csv', low_memory=False)
data.head()
# Out:
#    Unnamed: 0      hhcode       psu province region district  sec  idc  \
# 0           0  1111000101  11110001       KP  rural  Chitral  00B    1
# 1           1  1111000101  11110001       KP  rural  Chitral  00B    2
# 2           2  1111000101  11110001       KP  rural  Chitral  00B    3
# 3           3  1111000101  11110001       KP  rural  Chitral  00B    4
# 4           4  1111000101  11110001       KP  rural  Chitral  00B    5
#
#                  sbq02         sbq03  ... sbq62 sbq63  age  \
# 0                 Head                ...     0     0   81
# 1               Spouse  Family Elder  ...     0     0   70
# 2         Son/Daughter  Family Elder  ...     0     0   44
# 3  Son/Daughter-in-law  Family Elder  ...     0     0   37
# 4          Grand Child  Family Elder  ...     0     0   12
#
#                      sbq07  sbq08  sbq09 sbq10 sbq11  weights   age_bin
# 0        Currently Married      2     98    98   yes    168.0    senior
# ...

# %% [markdown]
# # District Level

# %%
district = data['district'].unique().tolist()

# %%
for x in district:
    data1 = data[data.district == x]
    data1.to_csv(('dist/year_2007/'+ str(x) + '_2007.csv'))

# %% [markdown]
# # Province Level

# %%
province = data['province'].unique().tolist()

# %%
for x in province:
    data1 = data[data.province == x]
    data1.to_csv(('../../province/year_2015/'+ str(x) + '_2015.csv'))
